# %%
username = "admin"
password = "1234"

user_input = input()
pass_input = input()
if(user_input == username and pass_input == password):
    print("Login Successful")
else:
    print("Invalid Credentials")
