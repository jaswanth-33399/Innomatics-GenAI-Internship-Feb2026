# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for i in messages:
  length = len(i)
  print(f"Message: {i} , Length: {length}")
  if(length > 10):
    print("Message is too long")
# Out:
# Message: Hi , Length: 2
# Message: Welcome to the platform , Length: 23
# Message is too long
# Message: OK , Length: 2
